# %% [markdown]
# Priyal Gupta
# PRN - 25070123087
# Experiment 6
# Aim of Experiment: Study of conditional statements in Python

# %%
# Q1). Check whether a given number is positive negative or zero

num = int(input("Enter a number: "))

if num > 0:
    print("The number is positive.")
elif num < 0:
    print("The number is negative.")
else:
    print("The number is zero.")
# Out:
# Enter a number: -62
# The number is negative.

# %%
# Q2). Check whether a given number is even or odd

num = int(input("Enter a number: "))

if num % 2 == 0:
 print("The given number is even.")
else:
 print("The given number is odd.")
# Out:
# Enter a number: 22
# The given number is even.

# %%
# Q3). Find the largest number out of the three given numbers

a = int(input("Enter the first number:"))
b = int(input("Enter the second number:"))
c = int(input("Enter the third number:"))
if a >= b and a >= c:
 print("a is the largest number.")
elif b >= a and b >= c:
 print("b is the largest number.")
else:
 print("c is the largest number.")
# Out:
# Enter the first number:6
# Enter the second number:6
# Enter the third number:3
# a is the largest number.

# %%
# Q4). Get thbe input from the user for one subject and
# Calculate grade using if else if

marks = float(input("Enter your marks:"))

if marks >= 90:
 print("Grade: A")
elif marks >= 75:
  print("Grade: B")
elif marks >= 60:
  print("Grade: C")
elif marks >=40:
  print("Grade: D")
else:
  print("Grade: F")
# Out:
# Enter your marks:86.2
# Grade: B

# %%
# Q5). To find if the given year is a leap year or not

year = int(input("Enter a year:"))
if year % 4 == 0 or (year % 100 != 0  and year % 400 == 0):
 print("The given year is a leap year.")
else:
  print("The given year is not a leap year.")
# Out:
# Enter a year:2000
# The given year is a leap year.

# %%
# Q6). Write a python program to calculate the gross salary of an employee
# if basic <= 10000: HRA

# otherwise :HRA = 30%, DA = 95%

basic = float(input("Enter the basic salary: "))

if basic <= 10000:
    hra = 0.2 * basic
    da = 0.8 * basic
elif basic <= 20000:
    hra = 0.25 * basic
    da = 0.90 * basic
else:
    hra = 0.3 * basic
    da = 0.95 * basic

gross = basic + hra + da
print("The gross salary of the employee is:", gross)
# Out:
# Enter the basic salary: 10000
# The gross salary of the employee is: 20000.0

# %%
# Q7). Write a pyhon program o calculate the income tax based on annual income
# upto 2,50,000: No tax
# 2,50,001 - 5,00,000: 5%
# 5,00,001 - 10,00,000:20%
# Above 10,00,000 :30%

income = float(input("Enter your annual income: "))
if income <= 250000:
    tax = 0
    print("You are not taxable.")
elif income <= 500000:
  tax = (income - 250000) * 0.05
  print("Your income tax is:", tax)
elif income <= 1000000:
  tax =  (250000 * 0.05)+(income - 500000) * 0.2
  print("Your income tax is:", tax)
else:
  tax = (250000 * 0.05) + (500000 * 0.20) + ((income - 1000000) * 0.3)
  print("Your income tax is:", tax)
# Out:
# Enter your annual income: 1200000
# Your income tax is: 172500.0

# %%
# Q8).Write python program to check if a given character is a vowel or a
#     consonant.

ch = input("Enter a character: ")
if ch in "aeiouAEIOU":
 print("The given character is a vowel.")
else:
  print ("The given character is a consonant.")
# Out:
# Enter a character: l
# The given character is a consonant.

# %%
# Q9). Write a python program to increment the date month and the year

date = input("Enter date in dd/mm/yyyy format: ")

dd, mm, yy = map(int, date.split("/"))


if mm in (1, 3, 5, 7, 8, 10, 12):
    max1 = 31
elif mm in (4, 6, 9, 11):
    max1 = 30
elif mm == 2:
    if (yy % 4 == 0 and yy % 100 != 0) or (yy % 400 == 0):
        max1 = 29
    else:
        max1 = 28
else:
    print("Date is invalid")
    exit()

if dd < 1 or dd > max1:
    print("Date is invalid")

elif dd == max1 and mm != 12:
    dd = 1
    mm += 1
    print("The incremented date is:", dd, mm, yy)

elif dd == 31 and mm == 12:
    dd = 1
    mm = 1
    yy += 1
    print("The incremented date is:", dd, mm, yy)

else:
    dd += 1
    print("The incremented date is:", dd, mm, yy)
# Out:
# Enter date in dd/mm/yyyy format: 31/01/2007
# The incremented date is: 1 2 2007
